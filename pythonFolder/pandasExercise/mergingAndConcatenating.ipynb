# %%
import pandas as pd

# %%
bios = pd.read_csv('bios.csv')

# %%
nocs = pd.read_csv('noc_regions.csv')

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='inner')

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=False)
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_country_full notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name', 'NOC_x', 'born_country_full']]
# Out:
# pandas.core.series.Series

# %%
# concat
usa = bios[bios['born_country'] == 'USA']
gbr = bios[bios['born_country'] == 'GBR']

new_df = pd.concat([usa, gbr], axis=0, ignore_index=True)
# Out:
#        athlete_id                name   born_date         born_city  \
# 0              55       Monique Javer  1967-07-22        Burlingame
# 1             964    Xóchitl Escobedo  1968-09-17       West Covina
# 2             965   Angélica Gavaldón  1973-10-03         El Centro
# 3            1238      Bert Schneider  1897-07-01         Cleveland
# 4            1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...           ...                 ...         ...               ...
# 15428      148512  Benjamin Alexander  1983-05-08            London
# 15429      148517       Ashley Watson  1993-10-28      Peterborough
# 15430      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 15431      149041          Axel Brown  1992-04-02         Harrogate
# 15432      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#       born_region born_country                  NOC  height_cm  weight_kg  \
# 0      California          USA        Great Britain      177.0       64.0
# ...
